# %%
import json
import requests
import urllib 
import time
user='user_name'
password='****'
url='http://'
module='modul_name'

# %%
# Preparing the API cals for ingestion

r= requests.get(url+'/ping')
print(r.json())
r= requests.post(url+'/login', json={"identifier":user,"password":password})
token=r.json()['token']
print(token)
# Out:
# {'featureFlags': {'AbstractionLayer': {'major': 1, 'minor': 0, 'compatibility': [0], 'freezone': 'first version of abstraction layer, supporting meta, pivotSource, branch, versioning.'}, 'ArrayDimensions': {'major': 1, 'minor': 0, 'compatibility': [], 'freezone': ''}, 'AuthSystem': {'major': 2, 'minor': 0, 'compatibility': [], 'freezone': ''}, 'MultiVersionedTableInCalculator': {'major': 1, 'minor': 0, 'compatibility': [], 'freezone': ''}, 'AutoCube': {'major': 1, 'minor': 0, 'compatibility': [0], 'freezone': 'AutoCube + DataModel Import + DataModel Export APIs)'}, 'MultiFunctionInCalculatorRequest': {'major': 1, 'minor': 0, 'compatibility': [], 'freezone': ''}, 'Group': {'major': 2, 'minor': 0, 'compatibility': [], 'freezone': 'Contain NonInjective group'}, 'PostAggregation': {'major': 1, 'minor': 0, 'compatibility': [0], 'freezone': 'PA key is a list of dimensions and multiple PAs are supported for a single metric'}, 'Monitoring': {'major': 5, 'minor': 0, 'compatibility': [0], 'fre
# ...

# %%
r_get = requests.get(url+'/modules',  headers={'Authorization': f'{token}'})
r_put = requests.put(url+'/modules', data={"key": "idf_trt_sit"})
r_del = requests.delete(url+'/modules/')

# %%
path = "C:/Users/NurlanAkbarli/Documents/osg323/"  #path
json_data=json.load(open(path+'situation_name.json','rb')) #body
print(json_data[0])
# Out:
# {'module': 'Result_last', 'name': 'situation_name11', 'key': 'idf_trt_sit', 'values': {'M-20211231-ABL_ADJUSTMENT- flux n° 2 - 9220106301002 - Pré cadrage ABL_ADJUSTMENT': ['922010630100219211'], 'SSU_test2': ['-987007', '-921814', '-871303', '-960604'], 'M-20210930-ABL_ADJUSTMENT- flux n° 9 - 9211006301009 - Pré cadrage ABL_ADJUSTMENT': ['921100630100919031', '921100630100919021'], 'M-20220630-ABL_ADJUSTMENT- flux n° 511 - 9220724301001 - RERUN BAIL IN => Pré cadrage ABL_ADJUSTMENT': ['922072430100119211', '922072430100119071', '922072430100119021', '922072430100119041'], 'M-20221130-ABL_ADJUSTMENT- flux n° 6 - 9221206301006 - Pré cadrage ABL_ADJUSTMENT': ['922120630100619031', '922120630100619041', '922120630100619611', '922120630100619071', '922120630100619211', '922120630100619021'], 'M-20220430-ABL_ADJUSTMENT- flux n° 154 - 9220510301033 - Pré cadrage ABL_ADJUSTMENT': ['922051030103319071', '922051030103319031', '922051030103319021', '922051030103319611', '922051030103319211', '
# ...

# %%
dim_group_name_list = []
dim_group_list = []

# %%
for data in json_data:
        dim_group_name_list.append(data["name"]) #on ajoute dat["name"] à dim_group_name_list
        dm_re = str(data).replace('\'', '"') #Le but de cette opération est de remplacer tous les apostrophes simples par des guillemets doubles dans la chaîne de caractères "str(data)".
        dim_group_list.append(dm_re)  #"str()" est utilisée pour convertir un objet en chaîne de caractères. Lâ "str(data)" convertit la variable "data" en une chaîne de caractères

# %%
APIcall = '/module/module_name/dimension/group/'

# %%
for index in range (0,len(dim_group_list)):
    APIcallDimGroup = APIcall + dim_group_name_list[index]

# %%
r = requests.put(url+APIcallDimGroup, headers={'Authorization': f'{token}','Accept' : 'application/json', 'Content-Type':'application/json'},data=dim_group_list[index])
    # vérifier si la requête a réussi
if r.status_code == 204:
        print(f"succès!")
else:
        print(f"Erreur ")
# Out:
# Erreur

# %%
r_del = requests.delete(url+APIcallDimGroup, headers={'Authorization': f'{token}'})
if r.status_code == 200:
    print(f"succès!")
else:
    print(f"Erreur ")
# Out:
# Erreur

# %%
r_post = requests.post(url+APIcallDimGroup, headers={'Authorization': f'{token}'})
if r.status_code == 201:
    print(f"succès!")
else:
    print(f"Erreur ")
# Out:
# Erreur
